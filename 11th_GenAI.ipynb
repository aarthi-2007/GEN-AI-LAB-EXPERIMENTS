# %% [markdown]
# <a href="https://colab.research.google.com/github/aarthi-2007/GEN-AI-LAB-EXPERIMENTS/blob/main/11th_GenAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
from diffusers import StableDiffusionPipeline
import torch

image_prompt = "An illustration representing the benefits of renewable energy, digital art"

sd_pipe = StableDiffusionPipeline.from_pretrained(
    "runwayml/stable-diffusion-v1-5",
    torch_dtype=torch.float16
).to("cuda")

image = sd_pipe(
    image_prompt,
    num_inference_steps=25
).images[0]

image.save("content_image.png")

print("Image saved as content_image.png")
# Out:
# Flax classes are deprecated and will be removed in Diffusers v0.40.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v0.40.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# ...
#   0%|          | 0/25 [00:00<?, ?it/s]
# Image saved as content_image.png

# %%
# !pip install gTTS
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 4.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.4.2
#     Uninstalling click-8.4.2:
#       Successfully uninstalled click-8.4.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# wandb 0.28.1 requires click>=8.2.0, but you have click 8.1.8 which is incompatible.
# huggingface-hub 1.27.0 requires click<9.0.0,>=8.4.2, but you have click 8.1.8 which is incompatible.
# spacy 3.8.15 requires click<9.0.0,>=8.2.1, but you have click 8.1.8 which is incompatible.
# ...

# %%
from gtts import gTTS

print("gTTS is working!")
# Out:
# gTTS is working!

# %%
from gtts import gTTS

generated_text = "Renewable energy is beneficial because it reduces pollution and provides clean and sustainable energy for the future."

tts = gTTS(
    text=generated_text,
    lang="en"
)

tts.save("content_audio.mp3")

print("Audio saved as content_audio.mp3")
# Out:
# Audio saved as content_audio.mp3
